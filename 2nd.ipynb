# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from skimage.transform import rotate

# %%
vid=cv2.VideoCapture(0)
vid
# Out:
# < cv2.VideoCapture 000001C43AAA8DB0>

# %%
vid.isOpened()
# Out:
# True

# %%
k=vid.read()

# %%
type(k), len(k)
# Out:
# (tuple, 2)

# %%
k
# Out:
# (True,
#  array([[[27, 27, 27],
#          [27, 27, 27],
#          [27, 27, 27],
#          ...,
#          [27, 27, 27],
#          [27, 27, 27],
#          [27, 27, 27]],
#
#         [[27, 27, 27],
#          [27, 27, 27],
#          [27, 27, 27],
#          ...,
#          [27, 27, 27],
#          [27, 27, 27],
#          [27, 27, 27]],
#
#         [[27, 27, 27],
#          [27, 27, 27],
#          [27, 27, 27],
#          ...,
#          [27, 27, 27],
#          [27, 27, 27],
#          [27, 27, 27]],
#
#         ...,
#
#         [[27, 27, 27],
#          [27, 27, 27],
#          [26, 26, 26],
#          ...,
#          [27, 27, 27],
#          [26, 26, 26],
#          [26, 26, 26]],
#
#         [[27, 27, 27],
#          [27, 27, 27],
#          [26, 26, 26],
#          ...,
#          [27, 27, 27],
#          [26, 26, 26],
#          [26, 26, 26]],
#
#         [[27, 27, 27],
#          [27, 27, 27],
#          [26, 26, 26],
#          ...,
#          [27, 27, 27],
# ...

# %%
flag, img= vid.read()

# %%
img.shape
# Out:
# (480, 640, 3)

# %%
if flag:
    plt.imshow(img[:,:,::-1])

# %%
for i in range(100):
    flag, img=vid.read()
    if flag:
        cv2.imshow('Previous',img)
        cv2.waitKey(1)

cv2.destroyAllWindows()

# %%
ord('A')   ## Ascii VAlue
# Out:
# 65

# %%
vid=cv2.VideoCapture(0)

while True:
    flag, img=vid.read()
    if flag:
        img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        
        x1,y1,w,h=(200,400,300,400)
        img_cropped=img[y1:y1+h,x1:x1+w,:]

        cv2.imshow('Previous',img_cropped)
        key=cv2.waitKey(1)
        if key == ord('x'):
            break
    
vid.release()
cv2.destroyAllWindows()

# %%
from time import sleep


fd=cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

vid=cv2.VideoCapture(0)

while True:
    flag, img=vid.read()
    if flag:
        img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        
        x1,y1,w,h=(200,400,300,400)
        faces=fd.detectMultiScale(img_gray,1.1,5)
        for x1,y1,w,h in faces:
            img_cropped=img[y1:y1+h,x1:x1+w,:]
            cv2.rectangle(
                img,
                pt1=(x1,y1),
                pt2=(x1+w,y1+h),
                color=(0,0,255),
                thickness=10

            )
        cv2.imshow('Preview',img)
        key=cv2.waitKey(1)
        if key == ord('x'):
            break
    else:
        break
    
vid.release()
cv2.destroyAllWindows()

# %%
from time import sleep


fd=cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

vid=cv2.VideoCapture(0)

while True:
    flag, img=vid.read()
    if flag:
        img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        
        x1,y1,w,h=(200,400,300,400)
        faces=fd.detectMultiScale(img_gray,1.1,5)
        for x1,y1,w,h in faces:
            img_cropped=img[y1:y1+h,x1:x1+w,:]
            cv2.rectangle(
                img,
                pt1=(x1,y1),
                pt2=(x1+w,y1+h),
                color=(0,0,255),
                thickness=10

            )
        cv2.imshow('Preview',img)
        key=cv2.waitKey(1)
        if key == ord('x'):
            break
    else:
        break
    
vid.release()
cv2.destroyAllWindows()

# %%
img=cv2.imread('one.jpg')
img2=cv2.imread('two.jfif')

# %%
img.shape, img2.shape
# Out:
# ((480, 771, 3), (183, 275, 3))

# %%
def showimg(im):
    plt.imshow(im[:,:,::-1])
    plt.show()

def imshow(im):
    cv2.imshow('Preview',im)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
showimg(img)
showimg(img2)

# %%
img_1=cv2.multiply(img2,5*np.ones(img2.shape).astype('uint8'))
showimg(img_1)

# %%
img_2=cv2.convertScaleAbs(img2,alpha=5,beta=40)
showimg(img_2)

# %%
img_3=cv2.resize(img,(400,400),interpolation=cv2.INTER_CUBIC)
img_3.shape
# Out:
# (400, 400, 3)

# %%
img_4=cv2.resize(img2,None,fx=2,fy=0.5,interpolation=cv2.INTER_CUBIC)
img_4.shape
# Out:
# (92, 550, 3)

# %%
img_rotated=rotate(img2,angle=30,resize=True)
imshow(img_rotated)
cv2.imshow('',i)
key=cv2.waitKey(1)
if key == ord('q'):
    repeat=False
    
cv2.destroyAllWindows()
